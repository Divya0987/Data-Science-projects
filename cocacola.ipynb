# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_excel(r"C:\Users\Divya\Desktop\MlAssign\IIT---05---ML\Datasets\Cocacola.xlsx")
df
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
df.shape
# Out:
# (42, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 804.0+ bytes

# %%
df.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Quarter    0
# Sales      0
# dtype: int64

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot()
# Out:
# <Axes: xlabel='Quarter'>

# %%
df['Quarter']
# Out:
# 0     Q1_86
# 1     Q2_86
# 2     Q3_86
# 3     Q4_86
# 4     Q1_87
# 5     Q2_87
# 6     Q3_87
# 7     Q4_87
# 8     Q1_88
# 9     Q2_88
# 10    Q3_88
# 11    Q4_88
# 12    Q1_89
# 13    Q2_89
# 14    Q3_89
# 15    Q4_89
# 16    Q1_90
# 17    Q2_90
# 18    Q3_90
# 19    Q4_90
# 20    Q1_91
# 21    Q2_91
# 22    Q3_91
# 23    Q4_91
# 24    Q1_92
# 25    Q2_92
# 26    Q3_92
# 27    Q4_92
# 28    Q1_93
# 29    Q2_93
# 30    Q3_93
# 31    Q4_93
# 32    Q1_94
# 33    Q2_94
# 34    Q3_94
# 35    Q4_94
# 36    Q1_95
# 37    Q2_95
# 38    Q3_95
# 39    Q4_95
# 40    Q1_96
# 41    Q2_96
# Name: Quarter, dtype: object

# %%
df["Quarter"] = pd.to_datetime(df["Quarter"].str.replace("Q1", "01").str.replace("Q2", "04").str.replace("Q3", "07").str.replace("Q4", "10"), format="%m_%y")

# %%
df.set_index("Quarter", inplace=True)

# %%
df.plot()
# Out:
# <Axes: xlabel='Quarter'>

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
model = ARIMA(df, order=(2, 0, 0))
# Out:
# C:\Users\Divya\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# C:\Users\Divya\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# C:\Users\Divya\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit()

# %%
forecast = model_fit.forecast(steps=30)

# %%
forecast
# Out:
# 1996-07-01    5026.525497
# 1996-10-01    4934.265823
# 1997-01-01    4834.476363
# 1997-04-01    4740.980803
# 1997-07-01    4652.119999
# 1997-10-01    4567.791575
# 1998-01-01    4487.751682
# 1998-04-01    4411.783490
# 1998-07-01    4339.679742
# 1998-10-01    4271.243869
# 1999-01-01    4206.289286
# 1999-04-01    4144.638904
# 1999-07-01    4086.124639
# 1999-10-01    4030.586959
# 2000-01-01    3977.874447
# 2000-04-01    3927.843389
# 2000-07-01    3880.357380
# 2000-10-01    3835.286955
# 2001-01-01    3792.509235
# 2001-04-01    3751.907592
# 2001-07-01    3713.371330
# 2001-10-01    3676.795384
# 2002-01-01    3642.080033
# 2002-04-01    3609.130632
# 2002-07-01    3577.857347
# 2002-10-01    3548.174914
# 2003-01-01    3520.002409
# 2003-04-01    3493.263022
# 2003-07-01    3467.883852
# 2003-10-01    3443.795704
# Freq: QS-OCT, Name: predicted_mean, dtype: float64

# %%
forecast.plot()
# Out:
# <Axes: >
