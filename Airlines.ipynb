# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_excel(r"C:\Users\Divya\Desktop\MlAssign\IIT---05---ML\Datasets\Airlines+Data.xlsx")
df
# Out:
#         Month  Passengers
# 0  1995-01-01         112
# 1  1995-02-01         118
# 2  1995-03-01         132
# 3  1995-04-01         129
# 4  1995-05-01         121
# ..        ...         ...
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306
#
# [96 rows x 2 columns]

# %%
df.tail()
# Out:
#         Month  Passengers
# 91 2002-08-01         405
# 92 2002-09-01         355
# 93 2002-10-01         306
# 94 2002-11-01         271
# 95 2002-12-01         306

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Month       96 non-null     datetime64[ns]
#  1   Passengers  96 non-null     int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 1.6 KB

# %%
df.describe()
# Out:
#                      Month  Passengers
# count                   96   96.000000
# mean   1998-12-16 05:00:00  213.708333
# min    1995-01-01 00:00:00  104.000000
# 25%    1996-12-24 06:00:00  156.000000
# 50%    1998-12-16 12:00:00  200.000000
# 75%    2000-12-08 18:00:00  264.750000
# max    2002-12-01 00:00:00  413.000000
# std                    NaN   71.918216

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 91    False
# 92    False
# 93    False
# 94    False
# 95    False
# Length: 96, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Month         0
# Passengers    0
# dtype: int64

# %%
df.set_index("Month", inplace=True)

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Passengers'])
plt.title('Airline Passengers')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.show()

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
model = ARIMA(df, order=(2, 0, 0))
# Out:
# C:\Users\Divya\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Divya\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Divya\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
model_fit = model.fit()

# %%
forecast = model_fit.forecast(steps=30)

# %%
forecast
# Out:
# 2003-01-01    310.307163
# 2003-02-01    305.550641
# 2003-03-01    298.491468
# 2003-04-01    291.210166
# 2003-05-01    284.316786
# 2003-06-01    277.962111
# 2003-07-01    272.155945
# 2003-08-01    266.867078
# 2003-09-01    262.054483
# 2003-10-01    257.676864
# 2003-11-01    253.695408
# 2003-12-01    250.074422
# 2004-01-01    246.781319
# 2004-02-01    243.786425
# 2004-03-01    241.062740
# 2004-04-01    238.585706
# 2004-05-01    236.332987
# 2004-06-01    234.284270
# 2004-07-01    232.421081
# 2004-08-01    230.726619
# 2004-09-01    229.185604
# 2004-10-01    227.784141
# 2004-11-01    226.509591
# 2004-12-01    225.350463
# 2005-01-01    224.296302
# 2005-02-01    223.337605
# 2005-03-01    222.465725
# 2005-04-01    221.672801
# 2005-05-01    220.951683
# 2005-06-01    220.295868
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
forecast.plot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
plt.plot(df.index,df['Passengers'])
plt.title('Airline Passengers')
plt.xlabel('Date')
plt.ylabel('Passengers')
plt.show()
